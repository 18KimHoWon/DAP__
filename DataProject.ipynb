# %% [markdown]
# <a href="https://colab.research.google.com/github/18KimHoWon/DAP__/blob/main/DataProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
agedf = pd.read_csv('Enter_korea_by_age.csv')
agedf.drop(['growth', 'share'], axis = 1, inplace=True)
agedf.head()
# Out:
#      date     nation  visitor  age0-20  ...  age31-40  age41-50  age51-60  age61
# 0  2019-1      China   392814    36520  ...    103657     48574     40893  40998
# 1  2019-1      Japan   206526    18015  ...     34165     39811     33857  20330
# 2  2019-1     Taiwan    87954    18888  ...     18595     18862      8169   4566
# 3  2019-1  Hong Kong    35896     3890  ...      7400      5461      4629   2137
# 4  2019-1      Macao     2570      223  ...       762       264       181     92
#
# [5 rows x 9 columns]

# %%
purposedf = pd.read_csv('Enter_korea_by_purpose.csv')
purposedf.drop(['growth', 'share'], axis = 1, inplace=True)
purposedf.head()
# Out:
#      date     nation  visitor  ...  official affairs  studying  others
# 0  2019-1      China   392814  ...               138      8793   60777
# 1  2019-1      Japan   206526  ...               127       785    4576
# 2  2019-1     Taiwan    87954  ...                22       180    1285
# 3  2019-1  Hong Kong    35896  ...                 2        90    1092
# 4  2019-1      Macao     2570  ...                 0        17      45
#
# [5 rows x 8 columns]

# %% [markdown]
# 우리나라를 방문한 사람들이 가진 국적 중 가장 많은 국적을 찾는다.

# %%
agedf.sort_values(by=['visitor'], ascending=False).drop_duplicates(['nation'])
# Out:
#         date           nation  visitor  ...  age41-50  age51-60  age61
# 420   2019-8            China   578112  ...     76689     57236  46840
# 121   2019-3            Japan   375119  ...     59631     47010  29468
# 542  2019-10           Taiwan   127944  ...     22929     18315  13589
# 325   2019-6              USA   105398  ...     17788     15491  10452
# 183   2019-4        Hong Kong    76104  ...     15750     12675   8376
# 187   2019-4         Thailand    69726  ...     10301      7013   4423
# 185   2019-4      Phillipines    66525  ...      8410      5904   4280
# 548  2019-10          Vietnam    64820  ...      9181      8616   5157
# 670  2019-12         Malaysia    57764  ...     11490      6354   3237
# 671  2019-12        Singapore    42216  ...      8774      5054   2581
# 210   2019-4           Russia    34205  ...      5078      3591   1853
# 186   2019-4        Indonesia    31427  ...      4424      3222   1830
# ...
